# %% [markdown]
# <h1>Final Code</h1>

# %%
import os
import time
import requests
import pandas as pd
from bs4 import BeautifulSoup
from concurrent.futures import ThreadPoolExecutor, as_completed
from threading import Lock
import random

# ✅ ScraperAPI key
API_KEY = "fb255ed807c12e5c03651908a491615f"
NUM_THREADS = 8  # Optimized for an 8-core laptop
MAX_RETRIES = 7  # Increased retries for better success
SAVE_INTERVAL = 10  # Save every 10 pages

# ✅ Path to save Excel file
save_path = r"E:\DHP\File_7.xlsx"

# ✅ Shared data storage (processed in batches)
all_data = []
lock = Lock()  # Thread safety

# ✅ User input for page range
start_page = int(input("Enter the starting page number: "))
end_page = int(input("Enter the ending page number: "))


def scrape_page(page_number):
    """Scrapes a single Stack Overflow page with retries and returns extracted data."""
    site = f"https://stackoverflow.com/questions?tab=newest&pagesize=50&page={page_number}"
    url = f"http://api.scraperapi.com?api_key={API_KEY}&url={site}"
    
    delay = 3  # Start with a higher delay to avoid rate limits

    for attempt in range(1, MAX_RETRIES + 1):
        try:
            response = requests.get(url, timeout=30)  # ⬆ Increased timeout to avoid read timeouts
            if response.status_code == 429:  # Rate limited
                wait_time = delay + random.uniform(1, 3)  # Randomized backoff
                print(f"⚠️ Rate limit hit on page {page_number}, retrying in {wait_time:.2f}s (Attempt {attempt}/{MAX_RETRIES})...")
                time.sleep(wait_time)
                delay *= 2  # Exponential backoff
                continue  # Retry request

            if response.status_code != 200:
                print(f"❌ Failed to fetch page {page_number}: {response.status_code}")
                return []

            soup = BeautifulSoup(response.text, "html.parser")
            questions = soup.find_all("div", class_="s-post-summary")

            page_data = []
            for question in questions:
                time_element = question.find("span", class_="relativetime")
                exact_time = time_element["title"] if time_element else "N/A"

                tags = [tag.get_text() for tag in question.find_all("a", class_="post-tag")]
                page_data.append([exact_time, ", ".join(tags)])

            print(f"✅ Scraped page {page_number} successfully!")

            return page_data  # Return extracted data

        except requests.exceptions.RequestException as e:
            print(f"⚠️ Error on page {page_number} (attempt {attempt}/{MAX_RETRIES}): {e}")
            time.sleep(delay + random.uniform(1, 3))  # Randomized retry delay
            delay *= 2  # Exponential backoff

    print(f"❌ Skipping page {page_number} after {MAX_RETRIES} failed attempts.")
    return []  # Return empty list if all retries fail


def save_to_excel():
    """Efficiently appends new data to the Excel file in batches."""
    with lock:
        if not all_data:
            return

        df = pd.DataFrame(all_data, columns=["Date", "Tags"])

        if os.path.exists(save_path):
            existing_df = pd.read_excel(save_path)
            df = pd.concat([existing_df, df], ignore_index=True)  # Append new data

        df.to_excel(save_path, index=False)
        print(f"💾 Data saved to: {save_path} (Total rows: {len(df)})")

        # ✅ Clear memory after saving
        all_data.clear()

# ✅ Parallel scraping with ThreadPoolExecutor
with ThreadPoolExecutor(max_workers=NUM_THREADS) as executor:
    future_to_page = {executor.submit(scrape_page, i): i for i in range(start_page, end_page + 1)}

    for i, future in enumerate(as_completed(future_to_page), start=1):
        result = future.result()
        with lock:
            all_data.extend(result)

        # ✅ Save every 10 pages
        if i % SAVE_INTERVAL == 0 and all_data:
            save_to_excel()

# ✅ Final save when all pages are done
if all_data:
    save_to_excel()

print("🎉 Data scraping completed successfully!")
# Out:
# ✅ Scraped page 52900 successfully!
# ✅ Scraped page 52904 successfully!
# ✅ Scraped page 52902 successfully!
# ✅ Scraped page 52905 successfully!
# ✅ Scraped page 52906 successfully!
# ✅ Scraped page 52910 successfully!
# ✅ Scraped page 52908 successfully!
# ✅ Scraped page 52911 successfully!
# ✅ Scraped page 52909 successfully!
# ✅ Scraped page 52907 successfully!
# ✅ Scraped page 52913 successfully!
# ✅ Scraped page 52914 successfully!
# ✅ Scraped page 52915 successfully!
# ✅ Scraped page 52917 successfully!
# ✅ Scraped page 52919 successfully!
# ✅ Scraped page 52920 successfully!
# 💾 Data saved to: E:\DHP\File_7.xlsx (Total rows: 68967)
# ✅ Scraped page 52918 successfully!
# ✅ Scraped page 52922 successfully!
# ✅ Scraped page 52923 successfully!
# ✅ Scraped page 52921 successfully!
# ✅ Scraped page 52916 successfully!
# ⚠️ Rate limit hit on page 52928, retrying in 4.83s (Attempt 1/7)...
# ✅ Scraped page 52924 successfully!
# ✅ Scraped page 52925 successfully!
# ✅ Scraped page 52912 successfully!
# ✅ Scraped page 52926 successfully!
# ✅ Scraped page 52927 successfully!
# ✅ Scraped page 52901 successfully!
# 💾 Data saved to: E:\DHP\File_7.xlsx (Total rows: 69467)
# ✅ Scraped page 52929 successfully!
# ✅ Scraped page 52933 successfully!
# ✅ Scraped page 52930 successfully!
# ✅ Scraped page 52934 successfully!
# ✅ Scraped page 52931 successfully!
# ✅ Scraped page 52903 successfully!
# ✅ Scraped page 52935 successfully!
# ✅ Scraped page 52928 successfully!
# ✅ Scraped page 52937 successfully!
# ✅ Scraped page 52942 successfully!
# 💾 Data saved to: E:\DHP\File_7.xlsx (Total rows: 69967)
# ✅ Scraped page 52944 successfully!
# ✅ Scraped page 52940 successfully!
# ✅ Scraped page 52943 successfully!
# ✅ Scraped page 52946 successfully!
# ✅ Scraped page 52941 successfully!
# ✅ Scraped page 52939 successfully!
# ✅ Scraped page 52938 successfully!
# ✅ Scraped page 52945 successfully!
# ✅ Scraped page 52947 successfully!
# 💾 Data saved to: E:\DHP\File_7.xlsx (Total rows: 70467)
# ✅ Scraped page 52949 successfully!
# ✅ Scraped page 52952 successfully!
# ✅ Scraped page 52951 successfully!
# ✅ Scraped page 52953 successfully!
# ✅ Scraped page 52950 successfully!
# ⚠️ Rate limit hit on page 52958, retrying in 5.59s (Attempt 1/7)...
# ✅ Scraped page 52957 successfully!✅ Scraped page 52955 successfully!
#
# ✅ Scraped page 52956 successfully!
# ✅ Scraped page 52932 successfully!✅ Scraped page 52954 successfully!
#
# ✅ Scraped page 52936 successfully!
# 💾 Data saved to: E:\DHP\File_7.xlsx (Total rows: 70967)
# ✅ Scraped page 52959 successfully!
# ✅ Scraped page 52961 successfully!
# ✅ Scraped page 52962 successfully!
# ✅ Scraped page 52964 successfully!
# ✅ Scraped page 52960 successfully!
# ✅ Scraped page 52966 successfully!
# ✅ Scraped page 52963 successfully!
# ✅ Scraped page 52958 successfully!
# ✅ Scraped page 52967 successfully!
# ✅ Scraped page 52969 successfully!
# ✅ Scraped page 52968 successfully!
# 💾 Data saved to: E:\DHP\File_7.xlsx (Total rows: 71467)
# ✅ Scraped page 52971 successfully!
# ✅ Scraped page 52973 successfully!
# ✅ Scraped page 52970 successfully!
# ✅ Scraped page 52974 successfully!✅ Scraped page 52972 successfully!
#
# ✅ Scraped page 52976 successfully!
# ✅ Scraped page 52977 successfully!
# ✅ Scraped page 52978 successfully!
# ✅ Scraped page 52981 successfully!
# ✅ Scraped page 52980 successfully!
# ⚠️ Error on page 52948 (attempt 1/7): HTTPConnectionPool(host='api.scraperapi.com', port=80): Read timed out. (read timeout=30)
# ✅ Scraped page 52983 successfully!
# 💾 Data saved to: E:\DHP\File_7.xlsx (Total rows: 71967)
# ✅ Scraped page 52982 successfully!
# ✅ Scraped page 52984 successfully!
# ✅ Scraped page 52985 successfully!
# ✅ Scraped page 52979 successfully!
# ✅ Scraped page 52986 successfully!
# ✅ Scraped page 52987 successfully!
# ✅ Scraped page 52988 successfully!
# ✅ Scraped page 52991 successfully!
# ✅ Scraped page 52990 successfully!✅ Scraped page 52989 successfully!
#
# 💾 Data saved to: E:\DHP\File_7.xlsx (Total rows: 72467)
# ✅ Scraped page 52948 successfully!
# ✅ Scraped page 52975 successfully!
# ✅ Scraped page 52993 successfully!
# ✅ Scraped page 52994 successfully!
# ✅ Scraped page 52992 successfully!
# ✅ Scraped page 52996 successfully!
# ✅ Scraped page 52997 successfully!
# ✅ Scraped page 52998 successfully!
# ⚠️ Error on page 52965 (attempt 1/7): HTTPConnectionPool(host='api.scraperapi.com', port=80): Read timed out. (read timeout=30)
# ✅ Scraped page 52999 successfully!
# ✅ Scraped page 53000 successfully!
# 💾 Data saved to: E:\DHP\File_7.xlsx (Total rows: 72967)
# ✅ Scraped page 53004 successfully!
# ✅ Scraped page 53006 successfully!
# ✅ Scraped page 53001 successfully!
# ✅ Scraped page 53003 successfully!
# ✅ Scraped page 53005 successfully!
# ✅ Scraped page 52995 successfully!
# ✅ Scraped page 53009 successfully!
# ✅ Scraped page 53008 successfully!
# ✅ Scraped page 52965 successfully!
# 💾 Data saved to: E:\DHP\File_7.xlsx (Total rows: 73467)
# ✅ Scraped page 53012 successfully!
# ✅ Scraped page 53011 successfully!
# ✅ Scraped page 53013 successfully!
# ✅ Scraped page 53015 successfully!
# ✅ Scraped page 53017 successfully!
# ✅ Scraped page 53014 successfully!
# ✅ Scraped page 53018 successfully!
# 💾 Data saved to: E:\DHP\File_7.xlsx (Total rows: 73967)
# ✅ Scraped page 53010 successfully!
# ✅ Scraped page 53016 successfully!
# ✅ Scraped page 53021 successfully!
# ✅ Scraped page 53023 successfully!
# ✅ Scraped page 53007 successfully!
# ✅ Scraped page 53022 successfully!
# ✅ Scraped page 53025 successfully!
# ✅ Scraped page 53020 successfully!
# ✅ Scraped page 53024 successfully!
# ✅ Scraped page 53028 successfully!
# ✅ Scraped page 53027 successfully!
# ✅ Scraped page 53026 successfully!
# 💾 Data saved to: E:\DHP\File_7.xlsx (Total rows: 74467)
# ✅ Scraped page 53030 successfully!
# ⚠️ Error on page 53002 (attempt 1/7): HTTPConnectionPool(host='api.scraperapi.com', port=80): Read timed out. (read timeout=30)
# ✅ Scraped page 53033 successfully!
# ✅ Scraped page 53032 successfully!
# ⚠️ Rate limit hit on page 53029, retrying in 5.42s (Attempt 1/7)...
# ✅ Scraped page 53031 successfully!
# ✅ Scraped page 53035 successfully!
# ✅ Scraped page 53037 successfully!
# ✅ Scraped page 53036 successfully!
# ✅ Scraped page 53038 successfully!
# ✅ Scraped page 53039 successfully!
# ✅ Scraped page 53034 successfully!
# ✅ Scraped page 53040 successfully!
# 💾 Data saved to: E:\DHP\File_7.xlsx (Total rows: 74967)
# ✅ Scraped page 53019 successfully!
# ✅ Scraped page 53041 successfully!
# ✅ Scraped page 53044 successfully!
# ✅ Scraped page 53042 successfully!
# ✅ Scraped page 53029 successfully!
# ✅ Scraped page 53002 successfully!
# ✅ Scraped page 53045 successfully!✅ Scraped page 53046 successfully!
#
# ✅ Scraped page 53049 successfully!
# ✅ Scraped page 53048 successfully!
# ✅ Scraped page 53050 successfully!
# ✅ Scraped page 53055 successfully!
# 💾 Data saved to: E:\DHP\File_7.xlsx (Total rows: 75467)
# ✅ Scraped page 53053 successfully!
# ✅ Scraped page 53052 successfully!
# ✅ Scraped page 53047 successfully!
# ✅ Scraped page 53059 successfully!
# ✅ Scraped page 53051 successfully!
# 💾 Data saved to: E:\DHP\File_7.xlsx (Total rows: 75967)
# ✅ Scraped page 53056 successfully!
# ✅ Scraped page 53062 successfully!
# ✅ Scraped page 53054 successfully!
# ✅ Scraped page 53061 successfully!
# ✅ Scraped page 53057 successfully!
# ✅ Scraped page 53058 successfully!
# ✅ Scraped page 53063 successfully!
# ✅ Scraped page 53066 successfully!
# ✅ Scraped page 53067 successfully!
# ✅ Scraped page 53064 successfully!
# ✅ Scraped page 53068 successfully!
# ✅ Scraped page 53065 successfully!
# 💾 Data saved to: E:\DHP\File_7.xlsx (Total rows: 76467)
# ✅ Scraped page 53069 successfully!
# ✅ Scraped page 53043 successfully!
# ✅ Scraped page 53072 successfully!
# ✅ Scraped page 53071 successfully!
# ✅ Scraped page 53078 successfully!
# ✅ Scraped page 53077 successfully!
# 💾 Data saved to: E:\DHP\File_7.xlsx (Total rows: 76967)
# ✅ Scraped page 53080 successfully!
# ✅ Scraped page 53073 successfully!
# ✅ Scraped page 53075 successfully!
# ✅ Scraped page 53079 successfully!
# ✅ Scraped page 53074 successfully!
# ✅ Scraped page 53076 successfully!
# ✅ Scraped page 53081 successfully!
# ✅ Scraped page 53084 successfully!
# ⚠️ Error on page 53060 (attempt 1/7): HTTPConnectionPool(host='api.scraperapi.com', port=80): Read timed out. (read timeout=30)
# ✅ Scraped page 53088 successfully!
# 💾 Data saved to: E:\DHP\File_7.xlsx (Total rows: 77467)
# ✅ Scraped page 53070 successfully!✅ Scraped page 53086 successfully!
#
# ✅ Scraped page 53089 successfully!
# ✅ Scraped page 53087 successfully!
# ✅ Scraped page 53082 successfully!
# ✅ Scraped page 53085 successfully!
# ✅ Scraped page 53090 successfully!
# ✅ Scraped page 53092 successfully!
# ✅ Scraped page 53093 successfully!
# ✅ Scraped page 53091 successfully!
# ✅ Scraped page 53083 successfully!
# ✅ Scraped page 53094 successfully!
# ⚠️ Rate limit hit on page 53099, retrying in 5.72s (Attempt 1/7)...
# ✅ Scraped page 53101 successfully!✅ Scraped page 53098 successfully!
#
# ✅ Scraped page 53096 successfully!
# 💾 Data saved to: E:\DHP\File_7.xlsx (Total rows: 77967)
# ✅ Scraped page 53095 successfully!
# ✅ Scraped page 53097 successfully!
# ✅ Scraped page 53100 successfully!
# ✅ Scraped page 53104 successfully!
# ✅ Scraped page 53106 successfully!
# ✅ Scraped page 53102 successfully!
# ✅ Scraped page 53105 successfully!
# ⚠️ Rate limit hit on page 53111, retrying in 5.78s (Attempt 1/7)...
# ✅ Scraped page 53099 successfully!
# ✅ Scraped page 53103 successfully!
# ✅ Scraped page 53060 successfully!
# ✅ Scraped page 53109 successfully!
# ✅ Scraped page 53110 successfully!
# 💾 Data saved to: E:\DHP\File_7.xlsx (Total rows: 78467)
# ✅ Scraped page 53108 successfully!
# ✅ Scraped page 53112 successfully!
# ✅ Scraped page 53107 successfully!
# ✅ Scraped page 53113 successfully!
# ✅ Scraped page 53115 successfully!
# ✅ Scraped page 53116 successfully!
# ✅ Scraped page 53120 successfully!
# ✅ Scraped page 53119 successfully!
# ✅ Scraped page 53118 successfully!
# ✅ Scraped page 53114 successfully!
# ✅ Scraped page 53111 successfully!
# ✅ Scraped page 53122 successfully!
# 💾 Data saved to: E:\DHP\File_7.xlsx (Total rows: 78967)
# ✅ Scraped page 53124 successfully!
# ✅ Scraped page 53121 successfully!
# ✅ Scraped page 53117 successfully!
# ✅ Scraped page 53123 successfully!
# ✅ Scraped page 53125 successfully!
# ✅ Scraped page 53131 successfully!
# ✅ Scraped page 53127 successfully!
# ✅ Scraped page 53130 successfully!
# ✅ Scraped page 53132 successfully!
# ✅ Scraped page 53126 successfully!
# ✅ Scraped page 53129 successfully!
# 💾 Data saved to: E:\DHP\File_7.xlsx (Total rows: 79467)
# ✅ Scraped page 53135 successfully!
# ✅ Scraped page 53128 successfully!
# ✅ Scraped page 53137 successfully!
# ✅ Scraped page 53139 successfully!
# ✅ Scraped page 53138 successfully!
# ✅ Scraped page 53133 successfully!
# ✅ Scraped page 53141 successfully!
# ✅ Scraped page 53140 successfully!
# ✅ Scraped page 53142 successfully!
# ✅ Scraped page 53136 successfully!
# ⚠️ Rate limit hit on page 53149, retrying in 4.64s (Attempt 1/7)...
# 💾 Data saved to: E:\DHP\File_7.xlsx (Total rows: 79967)
# ✅ Scraped page 53148 successfully!
# ✅ Scraped page 53147 successfully!
# ✅ Scraped page 53144 successfully!
# ✅ Scraped page 53151 successfully!
# ✅ Scraped page 53152 successfully!
# ✅ Scraped page 53143 successfully!
# ✅ Scraped page 53150 successfully!
# 💾 Data saved to: E:\DHP\File_7.xlsx (Total rows: 80467)
# ✅ Scraped page 53155 successfully!
# ✅ Scraped page 53149 successfully!
# ✅ Scraped page 53145 successfully!
# ✅ Scraped page 53153 successfully!
# ✅ Scraped page 53156 successfully!
# ✅ Scraped page 53146 successfully!
# ✅ Scraped page 53158 successfully!
# ⚠️ Rate limit hit on page 53163, retrying in 5.39s (Attempt 1/7)...
# ⚠️ Rate limit hit on page 53157, retrying in 4.76s (Attempt 1/7)...
# ✅ Scraped page 53159 successfully!
# ✅ Scraped page 53154 successfully!
# ✅ Scraped page 53161 successfully!
# ✅ Scraped page 53134 successfully!
# ✅ Scraped page 53162 successfully!
# 💾 Data saved to: E:\DHP\File_7.xlsx (Total rows: 80967)
# ✅ Scraped page 53164 successfully!
# ✅ Scraped page 53165 successfully!
# ✅ Scraped page 53166 successfully!
# ✅ Scraped page 53168 successfully!
# ✅ Scraped page 53167 successfully!
# ⚠️ Rate limit hit on page 53173, retrying in 4.82s (Attempt 1/7)...
# ⚠️ Rate limit hit on page 53172, retrying in 5.27s (Attempt 1/7)...
# ✅ Scraped page 53169 successfully!
# ✅ Scraped page 53163 successfully!
# ✅ Scraped page 53170 successfully!
# ✅ Scraped page 53160 successfully!
# ✅ Scraped page 53171 successfully!
# ✅ Scraped page 53157 successfully!
# 💾 Data saved to: E:\DHP\File_7.xlsx (Total rows: 81467)
# ✅ Scraped page 53178 successfully!
# ✅ Scraped page 53179 successfully!
# ✅ Scraped page 53174 successfully!
# ✅ Scraped page 53175 successfully!
# ✅ Scraped page 53177 successfully!
# ✅ Scraped page 53176 successfully!
# ✅ Scraped page 53173 successfully!
# ✅ Scraped page 53172 successfully!
# ✅ Scraped page 53182 successfully!
# ✅ Scraped page 53181 successfully!
# ✅ Scraped page 53184 successfully!
# ✅ Scraped page 53185 successfully!
# 💾 Data saved to: E:\DHP\File_7.xlsx (Total rows: 81967)
# ✅ Scraped page 53187 successfully!
# ✅ Scraped page 53190 successfully!
# ✅ Scraped page 53189 successfully!
# ✅ Scraped page 53191 successfully!
# ✅ Scraped page 53194 successfully!
# ✅ Scraped page 53192 successfully!
# ✅ Scraped page 53183 successfully!
# ✅ Scraped page 53186 successfully!
# ✅ Scraped page 53193 successfully!
# ✅ Scraped page 53196 successfully!
# 💾 Data saved to: E:\DHP\File_7.xlsx (Total rows: 82467)
# ✅ Scraped page 53197 successfully!
# ✅ Scraped page 53195 successfully!
# ✅ Scraped page 53198 successfully!
# ✅ Scraped page 53200 successfully!
# ✅ Scraped page 53201 successfully!
# ✅ Scraped page 53202 successfully!
# ✅ Scraped page 53203 successfully!
# ✅ Scraped page 53188 successfully!
# ✅ Scraped page 53205 successfully!✅ Scraped page 53204 successfully!
#
# ✅ Scraped page 53206 successfully!
# ✅ Scraped page 53207 successfully!
# ✅ Scraped page 53180 successfully!
# 💾 Data saved to: E:\DHP\File_7.xlsx (Total rows: 82967)
# ✅ Scraped page 53211 successfully!
# ✅ Scraped page 53210 successfully!
# ✅ Scraped page 53212 successfully!
# ✅ Scraped page 53214 successfully!
# ✅ Scraped page 53217 successfully!
# ✅ Scraped page 53218 successfully!
# ✅ Scraped page 53215 successfully!
# ✅ Scraped page 53216 successfully!
# 💾 Data saved to: E:\DHP\File_7.xlsx (Total rows: 83467)
# ✅ Scraped page 53220 successfully!
# ✅ Scraped page 53208 successfully!
# ✅ Scraped page 53219 successfully!
# ✅ Scraped page 53221 successfully!
# ✅ Scraped page 53223 successfully!
# ✅ Scraped page 53224 successfully!
# ✅ Scraped page 53222 successfully!
# ✅ Scraped page 53225 successfully!
# ✅ Scraped page 53209 successfully!
# ✅ Scraped page 53199 successfully!
# ✅ Scraped page 53226 successfully!
# ✅ Scraped page 53227 successfully!
# ✅ Scraped page 53229 successfully!
# ✅ Scraped page 53228 successfully!
# ✅ Scraped page 53232 successfully!
# ✅ Scraped page 53230 successfully!
# ✅ Scraped page 53231 successfully!
# ✅ Scraped page 53233 successfully!
# ✅ Scraped page 53237 successfully!
# ✅ Scraped page 53235 successfully!
# 💾 Data saved to: E:\DHP\File_7.xlsx (Total rows: 83967)
# ✅ Scraped page 53240 successfully!
# ✅ Scraped page 53239 successfully!
# ✅ Scraped page 53238 successfully!
# ✅ Scraped page 53241 successfully!
# ✅ Scraped page 53236 successfully!
# ✅ Scraped page 53245 successfully!
# ✅ Scraped page 53244 successfully!
# ✅ Scraped page 53243 successfully!
# ✅ Scraped page 53234 successfully!
# 💾 Data saved to: E:\DHP\File_7.xlsx (Total rows: 84467)
# ✅ Scraped page 53242 successfully!
# ✅ Scraped page 53247 successfully!
# ✅ Scraped page 53251 successfully!
# ✅ Scraped page 53248 successfully!
# ✅ Scraped page 53249 successfully!
# ⚠️ Error on page 53213 (attempt 1/7): HTTPConnectionPool(host='api.scraperapi.com', port=80): Read timed out. (read timeout=30)
# ✅ Scraped page 53253 successfully!
# ✅ Scraped page 53250 successfully!
# ✅ Scraped page 53255 successfully!
# ✅ Scraped page 53254 successfully!
# ✅ Scraped page 53256 successfully!
# 💾 Data saved to: E:\DHP\File_7.xlsx (Total rows: 84967)
# ✅ Scraped page 53260 successfully!
# ✅ Scraped page 53258 successfully!
# ✅ Scraped page 53257 successfully!
# ✅ Scraped page 53259 successfully!
# ✅ Scraped page 53213 successfully!
# ✅ Scraped page 53262 successfully!
# ✅ Scraped page 53263 successfully!
# ✅ Scraped page 53264 successfully!
# ✅ Scraped page 53265 successfully!
# ✅ Scraped page 53267 successfully!
# 💾 Data saved to: E:\DHP\File_7.xlsx (Total rows: 85467)
# ✅ Scraped page 53268 successfully!
# ✅ Scraped page 53261 successfully!
# ✅ Scraped page 53269 successfully!
# ✅ Scraped page 53266 successfully!
# ✅ Scraped page 53273 successfully!
# ✅ Scraped page 53272 successfully!
# ✅ Scraped page 53274 successfully!
# ✅ Scraped page 53270 successfully!
# ✅ Scraped page 53275 successfully!
# 💾 Data saved to: E:\DHP\File_7.xlsx (Total rows: 85967)
# ✅ Scraped page 53276 successfully!
# ✅ Scraped page 53278 successfully!
# ✅ Scraped page 53279 successfully!
# ✅ Scraped page 53271 successfully!
# ✅ Scraped page 53277 successfully!
# ✅ Scraped page 53281 successfully!
# ✅ Scraped page 53280 successfully!
# ⚠️ Error on page 53246 (attempt 1/7): HTTPConnectionPool(host='api.scraperapi.com', port=80): Read timed out. (read timeout=30)
# ✅ Scraped page 53282 successfully!
# ✅ Scraped page 53285 successfully!
# ✅ Scraped page 53283 successfully!
# ✅ Scraped page 53284 successfully!
# ✅ Scraped page 53287 successfully!
# ✅ Scraped page 53286 successfully!
# ✅ Scraped page 53291 successfully!
# ⚠️ Error on page 53252 (attempt 1/7): HTTPConnectionPool(host='api.scraperapi.com', port=80): Read timed out. (read timeout=30)
# 💾 Data saved to: E:\DHP\File_7.xlsx (Total rows: 86467)
# ✅ Scraped page 53292 successfully!
# ✅ Scraped page 53289 successfully!
# ✅ Scraped page 53290 successfully!
# ✅ Scraped page 53288 successfully!
# ✅ Scraped page 53297 successfully!
# ✅ Scraped page 53294 successfully!
# ✅ Scraped page 53246 successfully!
# ✅ Scraped page 53293 successfully!
# ✅ Scraped page 53296 successfully!
# ✅ Scraped page 53295 successfully!
# ✅ Scraped page 53301 successfully!
# ✅ Scraped page 53300 successfully!
# ✅ Scraped page 53298 successfully!
# ✅ Scraped page 53303 successfully!
# 💾 Data saved to: E:\DHP\File_7.xlsx (Total rows: 86967)
# ✅ Scraped page 53304 successfully!
# ✅ Scraped page 53305 successfully!
# ✅ Scraped page 53306 successfully!
# ✅ Scraped page 53299 successfully!
# ✅ Scraped page 53308 successfully!
# ✅ Scraped page 53307 successfully!
# ✅ Scraped page 53309 successfully!
# ✅ Scraped page 53310 successfully!
# ✅ Scraped page 53312 successfully!
# ✅ Scraped page 53311 successfully!
# ✅ Scraped page 53302 successfully!
# ✅ Scraped page 53314 successfully!
# ✅ Scraped page 53252 successfully!
# ✅ Scraped page 53315 successfully!
# ✅ Scraped page 53313 successfully!
# ✅ Scraped page 53316 successfully!
# 💾 Data saved to: E:\DHP\File_7.xlsx (Total rows: 87467)
# ✅ Scraped page 53320 successfully!
# ✅ Scraped page 53319 successfully!
# ✅ Scraped page 53318 successfully!
# ✅ Scraped page 53317 successfully!
# ✅ Scraped page 53321 successfully!
# ✅ Scraped page 53322 successfully!
# ✅ Scraped page 53324 successfully!
# ✅ Scraped page 53328 successfully!
# ✅ Scraped page 53326 successfully!
# ✅ Scraped page 53327 successfully!
# ✅ Scraped page 53325 successfully!
# ✅ Scraped page 53330 successfully!
# ⚠️ Rate limit hit on page 53335, retrying in 4.75s (Attempt 1/7)...✅ Scraped page 53332 successfully!
#
# ✅ Scraped page 53323 successfully!✅ Scraped page 53329 successfully!
#
# ✅ Scraped page 53333 successfully!
# 💾 Data saved to: E:\DHP\File_7.xlsx (Total rows: 87967)
# ✅ Scraped page 53334 successfully!
# ✅ Scraped page 53336 successfully!
# ✅ Scraped page 53338 successfully!
# ✅ Scraped page 53339 successfully!
# ✅ Scraped page 53342 successfully!
# ✅ Scraped page 53341 successfully!
# ✅ Scraped page 53331 successfully!
# ✅ Scraped page 53344 successfully!
# ✅ Scraped page 53340 successfully!
# ✅ Scraped page 53335 successfully!
# ✅ Scraped page 53343 successfully!
# ✅ Scraped page 53337 successfully!
# ✅ Scraped page 53345 successfully!
# ✅ Scraped page 53349 successfully!
# ✅ Scraped page 53348 successfully!
# ✅ Scraped page 53346 successfully!
# ✅ Scraped page 53350 successfully!
# 💾 Data saved to: E:\DHP\File_7.xlsx (Total rows: 88467)
# ✅ Scraped page 53347 successfully!
# ✅ Scraped page 53352 successfully!
# ✅ Scraped page 53351 successfully!
# ⚠️ Rate limit hit on page 53360, retrying in 5.37s (Attempt 1/7)...
# ✅ Scraped page 53353 successfully!
# ✅ Scraped page 53354 successfully!
# ✅ Scraped page 53358 successfully!
# ✅ Scraped page 53356 successfully!
# ✅ Scraped page 53357 successfully!
# ✅ Scraped page 53361 successfully!
# ✅ Scraped page 53359 successfully!
# ✅ Scraped page 53363 successfully!
# ✅ Scraped page 53365 successfully!
# ✅ Scraped page 53355 successfully!
# ✅ Scraped page 53364 successfully!
# ✅ Scraped page 53368 successfully!
# ✅ Scraped page 53362 successfully!
# ✅ Scraped page 53366 successfully!
# 💾 Data saved to: E:\DHP\File_7.xlsx (Total rows: 88967)
# ✅ Scraped page 53369 successfully!
# ✅ Scraped page 53371 successfully!
# ✅ Scraped page 53367 successfully!
# ✅ Scraped page 53360 successfully!
# ✅ Scraped page 53375 successfully!
# ✅ Scraped page 53378 successfully!
# ✅ Scraped page 53377 successfully!
# ✅ Scraped page 53372 successfully!
# ✅ Scraped page 53376 successfully!
# ✅ Scraped page 53370 successfully!
# ✅ Scraped page 53373 successfully!
# ✅ Scraped page 53379 successfully!
# 💾 Data saved to: E:\DHP\File_7.xlsx (Total rows: 89467)
# ✅ Scraped page 53383 successfully!
# ✅ Scraped page 53385 successfully!
# ✅ Scraped page 53380 successfully!
# ✅ Scraped page 53386 successfully!
# ✅ Scraped page 53384 successfully!
# ✅ Scraped page 53387 successfully!
# ✅ Scraped page 53374 successfully!
# ✅ Scraped page 53389 successfully!
# ✅ Scraped page 53388 successfully!
# ✅ Scraped page 53390 successfully!
# ✅ Scraped page 53391 successfully!
# 💾 Data saved to: E:\DHP\File_7.xlsx (Total rows: 89967)
# ✅ Scraped page 53392 successfully!
# ✅ Scraped page 53396 successfully!
# ✅ Scraped page 53393 successfully!
# ✅ Scraped page 53397 successfully!
# ✅ Scraped page 53398 successfully!
# ✅ Scraped page 53400 successfully!
# ✅ Scraped page 53382 successfully!
# 💾 Data saved to: E:\DHP\File_7.xlsx (Total rows: 90467)
# ✅ Scraped page 53401 successfully!
# ✅ Scraped page 53402 successfully!
# ✅ Scraped page 53403 successfully!
# ✅ Scraped page 53404 successfully!
# ✅ Scraped page 53394 successfully!
# ✅ Scraped page 53406 successfully!
# ✅ Scraped page 53405 successfully!
# ✅ Scraped page 53408 successfully!
# ⚠️ Rate limit hit on page 53412, retrying in 5.50s (Attempt 1/7)...⚠️ Rate limit hit on page 53411, retrying in 4.49s (Attempt 1/7)...
#
# 💾 Data saved to: E:\DHP\File_7.xlsx (Total rows: 90967)
# ✅ Scraped page 53410 successfully!
# ✅ Scraped page 53409 successfully!
# ✅ Scraped page 53407 successfully!
# ✅ Scraped page 53381 successfully!✅ Scraped page 53399 successfully!
#
# ✅ Scraped page 53395 successfully!
# ✅ Scraped page 53416 successfully!
# ✅ Scraped page 53415 successfully!
# ✅ Scraped page 53411 successfully!
# ✅ Scraped page 53418 successfully!
# ✅ Scraped page 53414 successfully!
# ✅ Scraped page 53417 successfully!
# ✅ Scraped page 53412 successfully!
# 💾 Data saved to: E:\DHP\File_7.xlsx (Total rows: 91467)
# ✅ Scraped page 53420 successfully!
# ✅ Scraped page 53421 successfully!
# ✅ Scraped page 53419 successfully!
# ✅ Scraped page 53422 successfully!
# ✅ Scraped page 53423 successfully!
# ✅ Scraped page 53424 successfully!
# ✅ Scraped page 53425 successfully!
# ✅ Scraped page 53426 successfully!
# ✅ Scraped page 53427 successfully!
# 💾 Data saved to: E:\DHP\File_7.xlsx (Total rows: 91967)
# ✅ Scraped page 53432 successfully!
# ✅ Scraped page 53434 successfully!
# ✅ Scraped page 53429 successfully!
# ✅ Scraped page 53431 successfully!
# ✅ Scraped page 53437 successfully!
# ✅ Scraped page 53436 successfully!
# ✅ Scraped page 53428 successfully!
# ✅ Scraped page 53413 successfully!
# ✅ Scraped page 53438 successfully!
# ✅ Scraped page 53435 successfully!
# 💾 Data saved to: E:\DHP\File_7.xlsx (Total rows: 92467)
# ✅ Scraped page 53430 successfully!
# ✅ Scraped page 53439 successfully!
# ✅ Scraped page 53440 successfully!
# ✅ Scraped page 53433 successfully!
# ✅ Scraped page 53443 successfully!
# ✅ Scraped page 53446 successfully!
# ✅ Scraped page 53441 successfully!
# ✅ Scraped page 53449 successfully!
# ✅ Scraped page 53444 successfully!
# ✅ Scraped page 53448 successfully!
# ✅ Scraped page 53447 successfully!
# ✅ Scraped page 53452 successfully!
# ✅ Scraped page 53450 successfully!
# ✅ Scraped page 53451 successfully!
# ✅ Scraped page 53453 successfully!
# 💾 Data saved to: E:\DHP\File_7.xlsx (Total rows: 92967)
# ✅ Scraped page 53442 successfully!
# ✅ Scraped page 53458 successfully!
# ✅ Scraped page 53455 successfully!
# ✅ Scraped page 53454 successfully!
# ✅ Scraped page 53460 successfully!
# ✅ Scraped page 53457 successfully!
# ✅ Scraped page 53459 successfully!
# ✅ Scraped page 53461 successfully!
# ✅ Scraped page 53463 successfully!
# ✅ Scraped page 53464 successfully!
# ✅ Scraped page 53462 successfully!
# ✅ Scraped page 53467 successfully!
# ✅ Scraped page 53465 successfully!
# ✅ Scraped page 53456 successfully!
# 💾 Data saved to: E:\DHP\File_7.xlsx (Total rows: 93467)
# ✅ Scraped page 53469 successfully!
# ✅ Scraped page 53470 successfully!
# ✅ Scraped page 53471 successfully!
# ✅ Scraped page 53473 successfully!
# ✅ Scraped page 53472 successfully!
# ✅ Scraped page 53474 successfully!
# ✅ Scraped page 53466 successfully!
# ✅ Scraped page 53476 successfully!
# ✅ Scraped page 53475 successfully!
# ✅ Scraped page 53478 successfully!
# ✅ Scraped page 53477 successfully!
# 💾 Data saved to: E:\DHP\File_7.xlsx (Total rows: 93967)
# ✅ Scraped page 53480 successfully!
# ✅ Scraped page 53481 successfully!
# ✅ Scraped page 53479 successfully!
# ✅ Scraped page 53482 successfully!
# ✅ Scraped page 53484 successfully!
# ✅ Scraped page 53468 successfully!
# ✅ Scraped page 53483 successfully!
# ✅ Scraped page 53488 successfully!
# ⚠️ Error on page 53445 (attempt 1/7): HTTPConnectionPool(host='api.scraperapi.com', port=80): Read timed out. (read timeout=30)
# ✅ Scraped page 53487 successfully!
# ✅ Scraped page 53485 successfully!
# ✅ Scraped page 53492 successfully!
# ✅ Scraped page 53489 successfully!
# ✅ Scraped page 53491 successfully!
# ✅ Scraped page 53495 successfully!
# ✅ Scraped page 53493 successfully!
# 💾 Data saved to: E:\DHP\File_7.xlsx (Total rows: 94467)
# ✅ Scraped page 53497 successfully!
# ✅ Scraped page 53494 successfully!
# ✅ Scraped page 53496 successfully!
# ✅ Scraped page 53445 successfully!
# ✅ Scraped page 53499 successfully!
# ✅ Scraped page 53502 successfully!
# ✅ Scraped page 53498 successfully!
# ✅ Scraped page 53503 successfully!
# ✅ Scraped page 53504 successfully!
# ✅ Scraped page 53507 successfully!
# 💾 Data saved to: E:\DHP\File_7.xlsx (Total rows: 94967)
# ✅ Scraped page 53500 successfully!
# ✅ Scraped page 53490 successfully!
# ✅ Scraped page 53509 successfully!
# ✅ Scraped page 53510 successfully!
# ✅ Scraped page 53506 successfully!
# ✅ Scraped page 53508 successfully!
# ✅ Scraped page 53511 successfully!
# ✅ Scraped page 53513 successfully!
# ✅ Scraped page 53512 successfully!
# ✅ Scraped page 53515 successfully!
# 💾 Data saved to: E:\DHP\File_7.xlsx (Total rows: 95467)
# ✅ Scraped page 53514 successfully!
# ✅ Scraped page 53486 successfully!
# ✅ Scraped page 53517 successfully!
# ✅ Scraped page 53518 successfully!
# ✅ Scraped page 53520 successfully!
# ✅ Scraped page 53521 successfully!
# ✅ Scraped page 53516 successfully!
# 💾 Data saved to: E:\DHP\File_7.xlsx (Total rows: 95967)
# ✅ Scraped page 53524 successfully!
# ✅ Scraped page 53526 successfully!
# ✅ Scraped page 53519 successfully!
# ✅ Scraped page 53527 successfully!
# ⚠️ Error on page 53501 (attempt 1/7): HTTPConnectionPool(host='api.scraperapi.com', port=80): Read timed out. (read timeout=30)
# 💾 Data saved to: E:\DHP\File_7.xlsx (Total rows: 96467)
# ⚠️ Error on page 53505 (attempt 1/7): HTTPConnectionPool(host='api.scraperapi.com', port=80): Read timed out. (read timeout=30)
# ✅ Scraped page 53529 successfully!
# ✅ Scraped page 53528 successfully!
# ✅ Scraped page 53523 successfully!
# ✅ Scraped page 53531 successfully!
# 💾 Data saved to: E:\DHP\File_7.xlsx (Total rows: 96967)
# ✅ Scraped page 53501 successfully!
# ✅ Scraped page 53532 successfully!
# ✅ Scraped page 53522 successfully!
# ✅ Scraped page 53505 successfully!
# ✅ Scraped page 53533 successfully!
# ✅ Scraped page 53536 successfully!
# ✅ Scraped page 53534 successfully!
# ✅ Scraped page 53535 successfully!
# 💾 Data saved to: E:\DHP\File_7.xlsx (Total rows: 97467)
# ✅ Scraped page 53538 successfully!
# ✅ Scraped page 53540 successfully!
# ✅ Scraped page 53542 successfully!
# ⚠️ Error on page 53525 (attempt 1/7): HTTPConnectionPool(host='api.scraperapi.com', port=80): Read timed out. (read timeout=30)
# ✅ Scraped page 53543 successfully!
# ✅ Scraped page 53537 successfully!
# ✅ Scraped page 53530 successfully!
# ✅ Scraped page 53545 successfully!
# 💾 Data saved to: E:\DHP\File_7.xlsx (Total rows: 97967)
# ✅ Scraped page 53544 successfully!
# ✅ Scraped page 53541 successfully!
# ✅ Scraped page 53548 successfully!
# ✅ Scraped page 53546 successfully!
# ✅ Scraped page 53550 successfully!
# ✅ Scraped page 53551 successfully!
# ✅ Scraped page 53547 successfully!
# ✅ Scraped page 53549 successfully!
# ✅ Scraped page 53552 successfully!
# ✅ Scraped page 53553 successfully!
# ✅ Scraped page 53554 successfully!
# ✅ Scraped page 53525 successfully!
# ✅ Scraped page 53556 successfully!
# 💾 Data saved to: E:\DHP\File_7.xlsx (Total rows: 98467)
# ✅ Scraped page 53558 successfully!
# ✅ Scraped page 53555 successfully!
# ✅ Scraped page 53539 successfully!
# ✅ Scraped page 53562 successfully!
# ✅ Scraped page 53557 successfully!
# ✅ Scraped page 53561 successfully!
# ✅ Scraped page 53559 successfully!
# ✅ Scraped page 53564 successfully!
# ✅ Scraped page 53563 successfully!
# ✅ Scraped page 53568 successfully!
# ✅ Scraped page 53567 successfully!
# ✅ Scraped page 53566 successfully!
# ✅ Scraped page 53569 successfully!
# ✅ Scraped page 53560 successfully!
# ✅ Scraped page 53570 successfully!
# 💾 Data saved to: E:\DHP\File_7.xlsx (Total rows: 98967)
# ✅ Scraped page 53572 successfully!
# ✅ Scraped page 53576 successfully!
# ✅ Scraped page 53571 successfully!
# ✅ Scraped page 53577 successfully!
# ✅ Scraped page 53580 successfully!
# ✅ Scraped page 53574 successfully!
# ✅ Scraped page 53575 successfully!
# ✅ Scraped page 53578 successfully!
# ✅ Scraped page 53581 successfully!
# ✅ Scraped page 53582 successfully!
# 💾 Data saved to: E:\DHP\File_7.xlsx (Total rows: 99467)
# ✅ Scraped page 53579 successfully!
# ✅ Scraped page 53586 successfully!
# ✅ Scraped page 53583 successfully!
# ✅ Scraped page 53573 successfully!
# ✅ Scraped page 53587 successfully!
# ✅ Scraped page 53588 successfully!
# ✅ Scraped page 53584 successfully!
# ✅ Scraped page 53593 successfully!
# ✅ Scraped page 53591 successfully!
# ✅ Scraped page 53592 successfully!
# 💾 Data saved to: E:\DHP\File_7.xlsx (Total rows: 99967)
# ✅ Scraped page 53590 successfully!
# ✅ Scraped page 53589 successfully!
# ✅ Scraped page 53596 successfully!
# ✅ Scraped page 53594 successfully!
# ✅ Scraped page 53599 successfully!
# ⚠️ Error on page 53565 (attempt 1/7): HTTPConnectionPool(host='api.scraperapi.com', port=80): Read timed out. (read timeout=30)
# ✅ Scraped page 53595 successfully!
# ✅ Scraped page 53585 successfully!
# ✅ Scraped page 53600 successfully!
# ✅ Scraped page 53598 successfully!
# 💾 Data saved to: E:\DHP\File_7.xlsx (Total rows: 100467)
# ✅ Scraped page 53603 successfully!
# ✅ Scraped page 53597 successfully!
# ✅ Scraped page 53605 successfully!
# ✅ Scraped page 53606 successfully!
# ⚠️ Rate limit hit on page 53610, retrying in 4.59s (Attempt 1/7)...
# ✅ Scraped page 53608 successfully!
# ✅ Scraped page 53609 successfully!
# ✅ Scraped page 53601 successfully!
# ✅ Scraped page 53565 successfully!
# ✅ Scraped page 53611 successfully!
# 💾 Data saved to: E:\DHP\File_7.xlsx (Total rows: 100967)
# ✅ Scraped page 53613 successfully!
# ✅ Scraped page 53607 successfully!
# ✅ Scraped page 53614 successfully!
# ✅ Scraped page 53612 successfully!
# ✅ Scraped page 53610 successfully!
# ✅ Scraped page 53602 successfully!
# ✅ Scraped page 53616 successfully!
# ✅ Scraped page 53621 successfully!
# ✅ Scraped page 53622 successfully!
# ✅ Scraped page 53620 successfully!
# 💾 Data saved to: E:\DHP\File_7.xlsx (Total rows: 101467)
# ✅ Scraped page 53623 successfully!
# ✅ Scraped page 53617 successfully!
# ✅ Scraped page 53615 successfully!
# ✅ Scraped page 53619 successfully!
# ✅ Scraped page 53627 successfully!
# ✅ Scraped page 53626 successfully!
# ✅ Scraped page 53618 successfully!
# ✅ Scraped page 53604 successfully!
# ✅ Scraped page 53624 successfully!
# ✅ Scraped page 53630 successfully!
# ✅ Scraped page 53629 successfully!
# ✅ Scraped page 53632 successfully!
# ✅ Scraped page 53633 successfully!
# ✅ Scraped page 53636 successfully!
# 💾 Data saved to: E:\DHP\File_7.xlsx (Total rows: 101967)
# ✅ Scraped page 53635 successfully!
# ✅ Scraped page 53634 successfully!
# ✅ Scraped page 53637 successfully!
# ✅ Scraped page 53639 successfully!
# ✅ Scraped page 53642 successfully!
# ✅ Scraped page 53638 successfully!
# ✅ Scraped page 53640 successfully!
# ✅ Scraped page 53641 successfully!
# ✅ Scraped page 53644 successfully!
# 💾 Data saved to: E:\DHP\File_7.xlsx (Total rows: 102467)
# ✅ Scraped page 53628 successfully!
# ✅ Scraped page 53645 successfully!
# ✅ Scraped page 53647 successfully!
# ✅ Scraped page 53649 successfully!
# ✅ Scraped page 53631 successfully!
# ✅ Scraped page 53650 successfully!
# ✅ Scraped page 53651 successfully!
# ✅ Scraped page 53652 successfully!
# 💾 Data saved to: E:\DHP\File_7.xlsx (Total rows: 102967)
# ✅ Scraped page 53654 successfully!
# ⚠️ Error on page 53625 (attempt 1/7): HTTPConnectionPool(host='api.scraperapi.com', port=80): Read timed out. (read timeout=30)
# ✅ Scraped page 53655 successfully!
# ✅ Scraped page 53657 successfully!
# ✅ Scraped page 53646 successfully!
# 💾 Data saved to: E:\DHP\File_7.xlsx (Total rows: 103467)
# ✅ Scraped page 53658 successfully!
# ✅ Scraped page 53659 successfully!
# ✅ Scraped page 53656 successfully!
# ✅ Scraped page 53660 successfully!
# ✅ Scraped page 53625 successfully!
# ✅ Scraped page 53661 successfully!
# ✅ Scraped page 53643 successfully!
# ✅ Scraped page 53664 successfully!
# ✅ Scraped page 53666 successfully!
# ✅ Scraped page 53665 successfully!
# ✅ Scraped page 53648 successfully!
# ✅ Scraped page 53667 successfully!
# 💾 Data saved to: E:\DHP\File_7.xlsx (Total rows: 103967)
# ✅ Scraped page 53653 successfully!
# ✅ Scraped page 53670 successfully!
# ✅ Scraped page 53662 successfully!
# ✅ Scraped page 53668 successfully!
# ✅ Scraped page 53671 successfully!
# ✅ Scraped page 53672 successfully!
# ✅ Scraped page 53673 successfully!
# ✅ Scraped page 53674 successfully!
# ✅ Scraped page 53676 successfully!
# ✅ Scraped page 53678 successfully!
# ✅ Scraped page 53677 successfully!
# ✅ Scraped page 53669 successfully!
# ✅ Scraped page 53675 successfully!
# ✅ Scraped page 53680 successfully!
# 💾 Data saved to: E:\DHP\File_7.xlsx (Total rows: 104467)
# ✅ Scraped page 53681 successfully!
# ✅ Scraped page 53683 successfully!
# ✅ Scraped page 53684 successfully!
# ✅ Scraped page 53686 successfully!
# ✅ Scraped page 53685 successfully!
# ✅ Scraped page 53679 successfully!
# ✅ Scraped page 53687 successfully!
# ✅ Scraped page 53688 successfully!
# ✅ Scraped page 53691 successfully!
# ✅ Scraped page 53693 successfully!✅ Scraped page 53663 successfully!
#
# ✅ Scraped page 53692 successfully!
# ✅ Scraped page 53690 successfully!
# 💾 Data saved to: E:\DHP\File_7.xlsx (Total rows: 104967)
# ✅ Scraped page 53698 successfully!
# ✅ Scraped page 53697 successfully!
# ✅ Scraped page 53701 successfully!
# ✅ Scraped page 53700 successfully!
# ✅ Scraped page 53694 successfully!
# ✅ Scraped page 53699 successfully!
# ✅ Scraped page 53702 successfully!
# ✅ Scraped page 53703 successfully!
# 💾 Data saved to: E:\DHP\File_7.xlsx (Total rows: 105467)
# ✅ Scraped page 53695 successfully!
# ✅ Scraped page 53704 successfully!
# ✅ Scraped page 53705 successfully!
# ⚠️ Rate limit hit on page 53709, retrying in 4.82s (Attempt 1/7)...
# ✅ Scraped page 53706 successfully!
# ✅ Scraped page 53710 successfully!
# ✅ Scraped page 53689 successfully!
# ✅ Scraped page 53682 successfully!
# ✅ Scraped page 53696 successfully!
# ✅ Scraped page 53708 successfully!
# ✅ Scraped page 53711 successfully!
# 💾 Data saved to: E:\DHP\File_7.xlsx (Total rows: 105967)
# ✅ Scraped page 53709 successfully!
# ✅ Scraped page 53715 successfully!
# ✅ Scraped page 53714 successfully!
# ✅ Scraped page 53718 successfully!
# ✅ Scraped page 53713 successfully!
# ✅ Scraped page 53721 successfully!
# ✅ Scraped page 53719 successfully!
# ✅ Scraped page 53712 successfully!
# ✅ Scraped page 53723 successfully!
# ✅ Scraped page 53724 successfully!
# 💾 Data saved to: E:\DHP\File_7.xlsx (Total rows: 106467)
# ✅ Scraped page 53716 successfully!
# ✅ Scraped page 53720 successfully!
# ✅ Scraped page 53727 successfully!
# ✅ Scraped page 53725 successfully!
# ✅ Scraped page 53728 successfully!
# ✅ Scraped page 53729 successfully!
# ✅ Scraped page 53730 successfully!
# ✅ Scraped page 53722 successfully!
# ✅ Scraped page 53732 successfully!
# ✅ Scraped page 53726 successfully!
# 💾 Data saved to: E:\DHP\File_7.xlsx (Total rows: 106967)
# ✅ Scraped page 53733 successfully!
# ✅ Scraped page 53707 successfully!
# ✅ Scraped page 53734 successfully!
# ✅ Scraped page 53731 successfully!
# ✅ Scraped page 53735 successfully!
# ✅ Scraped page 53737 successfully!
# ✅ Scraped page 53738 successfully!
# ✅ Scraped page 53739 successfully!
# ✅ Scraped page 53743 successfully!
# ✅ Scraped page 53741 successfully!
# ✅ Scraped page 53736 successfully!
# ✅ Scraped page 53744 successfully!✅ Scraped page 53745 successfully!
#
# ✅ Scraped page 53742 successfully!
# ✅ Scraped page 53740 successfully!
# ✅ Scraped page 53746 successfully!
# 💾 Data saved to: E:\DHP\File_7.xlsx (Total rows: 107467)
# ✅ Scraped page 53747 successfully!
# ✅ Scraped page 53749 successfully!
# ✅ Scraped page 53751 successfully!
# ✅ Scraped page 53750 successfully!
# ✅ Scraped page 53717 successfully!
# ✅ Scraped page 53755 successfully!
# ✅ Scraped page 53754 successfully!
# ✅ Scraped page 53748 successfully!
# ✅ Scraped page 53752 successfully!✅ Scraped page 53759 successfully!
#
# ✅ Scraped page 53756 successfully!✅ Scraped page 53757 successfully!
#
# ✅ Scraped page 53758 successfully!
# ✅ Scraped page 53761 successfully!
# ✅ Scraped page 53764 successfully!
# ✅ Scraped page 53762 successfully!
# ✅ Scraped page 53763 successfully!
# 💾 Data saved to: E:\DHP\File_7.xlsx (Total rows: 107967)
# ✅ Scraped page 53753 successfully!
# ✅ Scraped page 53766 successfully!
# ✅ Scraped page 53760 successfully!
# ✅ Scraped page 53767 successfully!
# ✅ Scraped page 53770 successfully!
# ✅ Scraped page 53774 successfully!
# ✅ Scraped page 53771 successfully!
# ✅ Scraped page 53765 successfully!
# ✅ Scraped page 53773 successfully!
# ✅ Scraped page 53775 successfully!
# ✅ Scraped page 53772 successfully!
# ✅ Scraped page 53777 successfully!
# ✅ Scraped page 53776 successfully!
# ✅ Scraped page 53778 successfully!
# ✅ Scraped page 53782 successfully!
# ✅ Scraped page 53781 successfully!
# 💾 Data saved to: E:\DHP\File_7.xlsx (Total rows: 108467)
# ✅ Scraped page 53783 successfully!
# ✅ Scraped page 53779 successfully!
# ✅ Scraped page 53769 successfully!
# ✅ Scraped page 53784 successfully!
# ✅ Scraped page 53786 successfully!
# ✅ Scraped page 53787 successfully!
# ✅ Scraped page 53780 successfully!
# ✅ Scraped page 53790 successfully!✅ Scraped page 53791 successfully!
#
# ✅ Scraped page 53793 successfully!
# ✅ Scraped page 53788 successfully!
# ✅ Scraped page 53792 successfully!
# 💾 Data saved to: E:\DHP\File_7.xlsx (Total rows: 108967)
# ✅ Scraped page 53795 successfully!
# ✅ Scraped page 53796 successfully!
# ✅ Scraped page 53794 successfully!
# ✅ Scraped page 53798 successfully!
# ✅ Scraped page 53797 successfully!
# ✅ Scraped page 53802 successfully!
# ✅ Scraped page 53803 successfully!
# ✅ Scraped page 53800 successfully!
# ✅ Scraped page 53799 successfully!
# ⚠️ Error on page 53768 (attempt 1/7): HTTPConnectionPool(host='api.scraperapi.com', port=80): Read timed out. (read timeout=30)
# 💾 Data saved to: E:\DHP\File_7.xlsx (Total rows: 109467)
# ✅ Scraped page 53804 successfully!
# ✅ Scraped page 53807 successfully!
# ✅ Scraped page 53785 successfully!
# ✅ Scraped page 53805 successfully!
# ✅ Scraped page 53810 successfully!
# ✅ Scraped page 53806 successfully!
# 💾 Data saved to: E:\DHP\File_7.xlsx (Total rows: 109967)
# ✅ Scraped page 53768 successfully!
# ✅ Scraped page 53812 successfully!
# ✅ Scraped page 53811 successfully!
# ✅ Scraped page 53814 successfully!
# ✅ Scraped page 53815 successfully!
# ⚠️ Error on page 53789 (attempt 1/7): HTTPConnectionPool(host='api.scraperapi.com', port=80): Read timed out. (read timeout=30)
# ✅ Scraped page 53808 successfully!
# ✅ Scraped page 53816 successfully!
# ✅ Scraped page 53817 successfully!
# 💾 Data saved to: E:\DHP\File_7.xlsx (Total rows: 110467)
# ✅ Scraped page 53809 successfully!
# ✅ Scraped page 53818 successfully!
# ✅ Scraped page 53819 successfully!
# ✅ Scraped page 53821 successfully!
# ✅ Scraped page 53789 successfully!
# ✅ Scraped page 53820 successfully!
# ✅ Scraped page 53801 successfully!
# ✅ Scraped page 53822 successfully!
# ✅ Scraped page 53826 successfully!
# ✅ Scraped page 53823 successfully!
# ✅ Scraped page 53827 successfully!
# ✅ Scraped page 53824 successfully!
# ✅ Scraped page 53828 successfully!
# ✅ Scraped page 53829 successfully!
# ✅ Scraped page 53831 successfully!
# ✅ Scraped page 53832 successfully!
# 💾 Data saved to: E:\DHP\File_7.xlsx (Total rows: 110967)
# ✅ Scraped page 53834 successfully!
# ✅ Scraped page 53836 successfully!
# ✅ Scraped page 53830 successfully!
# ✅ Scraped page 53837 successfully!
# ✅ Scraped page 53835 successfully!
# ✅ Scraped page 53838 successfully!
# ✅ Scraped page 53839 successfully!
# ✅ Scraped page 53841 successfully!
# ⚠️ Error on page 53813 (attempt 1/7): HTTPConnectionPool(host='api.scraperapi.com', port=80): Read timed out. (read timeout=30)
# ✅ Scraped page 53825 successfully!
# 💾 Data saved to: E:\DHP\File_7.xlsx (Total rows: 111467)
# ✅ Scraped page 53844 successfully!
# ✅ Scraped page 53845 successfully!
# ✅ Scraped page 53840 successfully!
# ✅ Scraped page 53842 successfully!
# ✅ Scraped page 53847 successfully!
# ✅ Scraped page 53846 successfully!
# ⚠️ Rate limit hit on page 53852, retrying in 5.99s (Attempt 1/7)...
# ✅ Scraped page 53850 successfully!
# ✅ Scraped page 53851 successfully!
# ✅ Scraped page 53849 successfully!
# ✅ Scraped page 53843 successfully!
# ✅ Scraped page 53848 successfully!
# ✅ Scraped page 53813 successfully!
# ✅ Scraped page 53855 successfully!
# ✅ Scraped page 53853 successfully!
# ✅ Scraped page 53854 successfully!
# 💾 Data saved to: E:\DHP\File_7.xlsx (Total rows: 111967)
# ✅ Scraped page 53857 successfully!
# ✅ Scraped page 53858 successfully!
# ✅ Scraped page 53859 successfully!
# ✅ Scraped page 53860 successfully!
# ✅ Scraped page 53863 successfully!
# ✅ Scraped page 53864 successfully!
# ✅ Scraped page 53861 successfully!
# ⚠️ Error on page 53833 (attempt 1/7): HTTPConnectionPool(host='api.scraperapi.com', port=80): Read timed out. (read timeout=30)✅ Scraped page 53856 successfully!
#
# ✅ Scraped page 53866 successfully!
# ✅ Scraped page 53865 successfully!
# ✅ Scraped page 53852 successfully!
# ✅ Scraped page 53862 successfully!
# ✅ Scraped page 53867 successfully!
# ✅ Scraped page 53868 successfully!
# ✅ Scraped page 53870 successfully!
# ✅ Scraped page 53875 successfully!
# ✅ Scraped page 53873 successfully!✅ Scraped page 53869 successfully!
#
# 💾 Data saved to: E:\DHP\File_7.xlsx (Total rows: 112467)
# ✅ Scraped page 53871 successfully!
# ✅ Scraped page 53874 successfully!
# ✅ Scraped page 53876 successfully!
# ✅ Scraped page 53878 successfully!
# ✅ Scraped page 53879 successfully!
# ✅ Scraped page 53882 successfully!
# ✅ Scraped page 53872 successfully!
# ✅ Scraped page 53877 successfully!
# ✅ Scraped page 53833 successfully!
# ✅ Scraped page 53881 successfully!
# ✅ Scraped page 53883 successfully!
# ✅ Scraped page 53880 successfully!
# ✅ Scraped page 53890 successfully!
# ✅ Scraped page 53884 successfully!
# ✅ Scraped page 53891 successfully!
# 💾 Data saved to: E:\DHP\File_7.xlsx (Total rows: 112967)
# ✅ Scraped page 53892 successfully!
# ✅ Scraped page 53893 successfully!
# ✅ Scraped page 53894 successfully!
# ✅ Scraped page 53895 successfully!
# ✅ Scraped page 53896 successfully!
# 💾 Data saved to: E:\DHP\File_7.xlsx (Total rows: 113467)
# ✅ Scraped page 53897 successfully!
# ✅ Scraped page 53899 successfully!
# ✅ Scraped page 53887 successfully!
# ✅ Scraped page 53885 successfully!
# ✅ Scraped page 53889 successfully!
# ✅ Scraped page 53900 successfully!
# ✅ Scraped page 53901 successfully!
# 💾 Data saved to: E:\DHP\File_7.xlsx (Total rows: 113967)
# ✅ Scraped page 53904 successfully!
# ✅ Scraped page 53903 successfully!
# ✅ Scraped page 53898 successfully!
# ✅ Scraped page 53902 successfully!
# ✅ Scraped page 53905 successfully!
# ✅ Scraped page 53907 successfully!
# ✅ Scraped page 53909 successfully!
# ✅ Scraped page 53908 successfully!
# ⚠️ Error on page 53886 (attempt 1/7): HTTPConnectionPool(host='api.scraperapi.com', port=80): Read timed out. (read timeout=30)
# ✅ Scraped page 53888 successfully!
# ✅ Scraped page 53912 successfully!
# ✅ Scraped page 53911 successfully!
# ✅ Scraped page 53913 successfully!
# ✅ Scraped page 53910 successfully!
# ✅ Scraped page 53914 successfully!
# ✅ Scraped page 53915 successfully!
# ✅ Scraped page 53906 successfully!
# ✅ Scraped page 53916 successfully!
# ✅ Scraped page 53919 successfully!
# 💾 Data saved to: E:\DHP\File_7.xlsx (Total rows: 114467)
# ✅ Scraped page 53920 successfully!
# ✅ Scraped page 53921 successfully!
# ✅ Scraped page 53886 successfully!
# ✅ Scraped page 53923 successfully!
# ✅ Scraped page 53922 successfully!
# ✅ Scraped page 53924 successfully!
# ✅ Scraped page 53917 successfully!
# ✅ Scraped page 53927 successfully!
# ✅ Scraped page 53928 successfully!
# ✅ Scraped page 53929 successfully!
# ✅ Scraped page 53926 successfully!
# ✅ Scraped page 53930 successfully!
# ✅ Scraped page 53931 successfully!✅ Scraped page 53918 successfully!
#
# ✅ Scraped page 53932 successfully!
# ✅ Scraped page 53933 successfully!✅ Scraped page 53935 successfully!
#
# ✅ Scraped page 53937 successfully!
# ✅ Scraped page 53934 successfully!
# 💾 Data saved to: E:\DHP\File_7.xlsx (Total rows: 114967)
# ✅ Scraped page 53941 successfully!
# ✅ Scraped page 53936 successfully!
# ✅ Scraped page 53939 successfully!
# ✅ Scraped page 53940 successfully!
# ✅ Scraped page 53938 successfully!
# ✅ Scraped page 53942 successfully!
# ✅ Scraped page 53943 successfully!
# ✅ Scraped page 53947 successfully!
# ✅ Scraped page 53946 successfully!
# ✅ Scraped page 53945 successfully!
# ✅ Scraped page 53944 successfully!
# ✅ Scraped page 53949 successfully!
# ✅ Scraped page 53948 successfully!
# ✅ Scraped page 53954 successfully!
# ✅ Scraped page 53955 successfully!
# ✅ Scraped page 53953 successfully!
# ✅ Scraped page 53952 successfully!
# ✅ Scraped page 53958 successfully!
# 💾 Data saved to: E:\DHP\File_7.xlsx (Total rows: 115467)
# ✅ Scraped page 53960 successfully!
# ✅ Scraped page 53957 successfully!
# ✅ Scraped page 53956 successfully!
# ✅ Scraped page 53961 successfully!
# ✅ Scraped page 53959 successfully!
# ✅ Scraped page 53951 successfully!
# ✅ Scraped page 53925 successfully!
# ✅ Scraped page 53963 successfully!
# ✅ Scraped page 53966 successfully!
# ✅ Scraped page 53965 successfully!
# ✅ Scraped page 53962 successfully!
# ✅ Scraped page 53964 successfully!
# ✅ Scraped page 53968 successfully!
# ✅ Scraped page 53967 successfully!
# 💾 Data saved to: E:\DHP\File_7.xlsx (Total rows: 115967)
# ✅ Scraped page 53969 successfully!
# ✅ Scraped page 53970 successfully!
# ✅ Scraped page 53971 successfully!
# ✅ Scraped page 53973 successfully!
# ✅ Scraped page 53975 successfully!
# ✅ Scraped page 53974 successfully!
# ✅ Scraped page 53976 successfully!
# ✅ Scraped page 53977 successfully!
# ✅ Scraped page 53981 successfully!
# ✅ Scraped page 53972 successfully!
# ✅ Scraped page 53980 successfully!
# ✅ Scraped page 53979 successfully!
# ✅ Scraped page 53978 successfully!
# ✅ Scraped page 53982 successfully!
# ✅ Scraped page 53983 successfully!
# ✅ Scraped page 53986 successfully!
# ✅ Scraped page 53990 successfully!
# ✅ Scraped page 53988 successfully!
# ✅ Scraped page 53989 successfully!
# ✅ Scraped page 53987 successfully!
# ✅ Scraped page 53950 successfully!
# 💾 Data saved to: E:\DHP\File_7.xlsx (Total rows: 116467)
# ✅ Scraped page 53991 successfully!
# ✅ Scraped page 53985 successfully!
# ✅ Scraped page 53992 successfully!
# ✅ Scraped page 53995 successfully!
# ✅ Scraped page 53994 successfully!
# ✅ Scraped page 53993 successfully!
# ✅ Scraped page 53996 successfully!
# ✅ Scraped page 53998 successfully!
# ✅ Scraped page 54000 successfully!
# ✅ Scraped page 53999 successfully!
# 💾 Data saved to: E:\DHP\File_7.xlsx (Total rows: 116967)
# ✅ Scraped page 53997 successfully!
# ✅ Scraped page 53984 successfully!
# 💾 Data saved to: E:\DHP\File_7.xlsx (Total rows: 117467)
# 💾 Data saved to: E:\DHP\File_7.xlsx (Total rows: 117967)
# 💾 Data saved to: E:\DHP\File_7.xlsx (Total rows: 118467)
# 💾 Data saved to: E:\DHP\File_7.xlsx (Total rows: 118967)
# 💾 Data saved to: E:\DHP\File_7.xlsx (Total rows: 119467)
# 💾 Data saved to: E:\DHP\File_7.xlsx (Total rows: 119967)
# 💾 Data saved to: E:\DHP\File_7.xlsx (Total rows: 120467)
# 💾 Data saved to: E:\DHP\File_7.xlsx (Total rows: 120967)
# 💾 Data saved to: E:\DHP\File_7.xlsx (Total rows: 121467)
# 💾 Data saved to: E:\DHP\File_7.xlsx (Total rows: 121967)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 102
#     100         # ✅ Save every 10 pages
#     101         if i % SAVE_INTERVAL == 0 and all_data:
# --> 102             save_to_excel()
#     104 # ✅ Final save when all pages are done
#     105 if all_data:
#
# Cell In[1], line 82, in save_to_excel()
#      79 df = pd.DataFrame(all_data, columns=["Date", "Tags"])
#      81 if os.path.exists(save_path):
# ---> 82     existing_df = pd.read_excel(save_path)
#      83     df = pd.concat([existing_df, df], ignore_index=True)  # Append new data
#      85 df.to_excel(save_path, index=False)
#
# File c:\Users\Hirak\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
#     499         engine_kwargs=engine_kwargs,
#     500     )
#     501 elif engine and engine != io.engine:
#     502     raise ValueError(
#     503         "Engine should not be specified when passing "
#     504         "an ExcelFile - ExcelFile already has the engine set"
#     505     )
#
# File c:\Users\Hirak\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\excel\_base.py:1567, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options, engine_kwargs)
#    1564 self.engine = engine
#    1565 self.storage_options = storage_options
# -> 1567 self._reader = self._engines[engine](
#    1568     self._io,
#    1569     storage_options=storage_options,
#    1570     engine_kwargs=engine_kwargs,
#    1571 )
#
# File c:\Users\Hirak\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\excel\_openpyxl.py:553, in OpenpyxlReader.__init__(self, filepath_or_buffer, storage_options, engine_kwargs)
#     541 """
#     542 Reader using openpyxl engine.
#     543
#    (...)
#     550     Arbitrary keyword arguments passed to excel engine.
#     551 """
#     552 import_optional_dependency("openpyxl")
# --> 553 super().__init__(
#     554     filepath_or_buffer,
#     555     storage_options=storage_options,
#     556     engine_kwargs=engine_kwargs,
#     557 )
#
# File c:\Users\Hirak\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\excel\_base.py:573, in BaseExcelReader.__init__(self, filepath_or_buffer, storage_options, engine_kwargs)
#     571 self.handles.handle.seek(0)
#     572 try:
# --> 573     self.book = self.load_workbook(self.handles.handle, engine_kwargs)
#     574 except Exception:
#     575     self.close()
#
# File c:\Users\Hirak\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\excel\_openpyxl.py:572, in OpenpyxlReader.load_workbook(self, filepath_or_buffer, engine_kwargs)
#     568 from openpyxl import load_workbook
#     570 default_kwargs = {"read_only": True, "data_only": True, "keep_links": False}
# --> 572 return load_workbook(
#     573     filepath_or_buffer,
#     574     **(default_kwargs | engine_kwargs),
#     575 )
#
# File c:\Users\Hirak\AppData\Local\Programs\Python\Python312\Lib\site-packages\openpyxl\reader\excel.py:348, in load_workbook(filename, read_only, keep_vba, data_only, keep_links, rich_text)
#     318 """Open the given filename and return the workbook
#     319
#     320 :param filename: the path to open or a file-like object
#    (...)
#     344
#     345 """
#     346 reader = ExcelReader(filename, read_only, keep_vba,
#     347                      data_only, keep_links, rich_text)
# --> 348 reader.read()
#     349 return reader.wb
#
# File c:\Users\Hirak\AppData\Local\Programs\Python\Python312\Lib\site-packages\openpyxl\reader\excel.py:291, in ExcelReader.read(self)
#     289 self.read_manifest()
#     290 action = "read strings"
# --> 291 self.read_strings()
#     292 action = "read workbook"
#     293 self.read_workbook()
#
# File c:\Users\Hirak\AppData\Local\Programs\Python\Python312\Lib\site-packages\openpyxl\reader\excel.py:147, in ExcelReader.read_strings(self)
#     145 strings_path = ct.PartName[1:]
#     146 with self.archive.open(strings_path,) as src:
# --> 147     self.shared_strings = reader(src)
#
# File c:\Users\Hirak\AppData\Local\Programs\Python\Python312\Lib\site-packages\openpyxl\reader\strings.py:16, in read_string_table(xml_source)
#      13 strings = []
#      14 STRING_TAG = '{%s}si' % SHEET_MAIN_NS
# ---> 16 for _, node in iterparse(xml_source):
#      17     if node.tag == STRING_TAG:
#      18         text = Text.from_tree(node).content
#
# File c:\Users\Hirak\AppData\Local\Programs\Python\Python312\Lib\xml\etree\ElementTree.py:1238, in iterparse.<locals>.iterator(source)
#    1236 yield from pullparser.read_events()
#    1237 # load event buffer
# -> 1238 data = source.read(16 * 1024)
#    1239 if not data:
#    1240     break
#
# File c:\Users\Hirak\AppData\Local\Programs\Python\Python312\Lib\zipfile\__init__.py:989, in ZipExtFile.read(self, n)
#     987 self._offset = 0
#     988 while n > 0 and not self._eof:
# --> 989     data = self._read1(n)
#     990     if n < len(data):
#     991         self._readbuffer = data
#
# File c:\Users\Hirak\AppData\Local\Programs\Python\Python312\Lib\zipfile\__init__.py:1065, in ZipExtFile._read1(self, n)
#    1063 elif self._compress_type == ZIP_DEFLATED:
#    1064     n = max(n, self.MIN_READ_SIZE)
# -> 1065     data = self._decompressor.decompress(data, n)
#    1066     self._eof = (self._decompressor.eof or
#    1067                  self._compress_left <= 0 and
#    1068                  not self._decompressor.unconsumed_tail)
#    1069     if self._eof:
#
# KeyboardInterrupt:
